# %%
import pandas as pd
import numpy as np
import requests
import json

# %% [markdown]
# # Notebook de contôle

# %% [markdown]
# ## Contrôles à appliquer avant le workflow Dagster

# %%
observation_date = "2022-08-29"
corpus_end_year = 2022

# %%
df = pd.read_json(f'01_raw/{observation_date}/exportDonnees_barometre_complet_{observation_date}.json')
df.shape
# Out:
# (43309, 20)

# %% [markdown]
# ### Vérif fichier bien formé

# %%
df[df["dc:identifiers"] == "SCOPUS_ID:84961134992"][["dc:identifiers","@auid","@afids","ce:indexed-name"]]
# Out:
#               dc:identifiers        @auid    @afids ce:indexed-name
# 10805  SCOPUS_ID:84961134992  56656653900  60110764       Rageot M.
# 10806  SCOPUS_ID:84961134992  56656653900  60110763       Rageot M.
# 10807  SCOPUS_ID:84961134992   6603126272  60110764       Regert M.
# 10808  SCOPUS_ID:84961134992   7003877322  60110763    Filippi J.J.
# 10809  SCOPUS_ID:84961134992   7004449219  60110763    Fernandez X.

# %% [markdown]
# ### Vérif affiliations à ajouter

# %%
data = df[["dc:identifiers","prism:doi","reference","annee_pub","@afids","mentionAffil_reconstruct","@auid","ce:indexed-name","corresponding_author","Is_dc:creator"]]
data.columns = ['source_id', 'doi',"scopus_title",'year', 'aff_scopus_id','aff_source_text','author_id','author_name','corresponding_author','creator_author']
df_authors = data.groupby('source_id')['author_name'].apply(list).reset_index(name='all_authors')
df_authors['all_authors'] = df_authors["all_authors"].apply('|'.join)
df_reference_data = pd.merge(data,df_authors, left_on='source_id', right_on='source_id')

# %%
df_affiliations = pd.read_json('03_primary/referentiel_structures.json')
set_affiliations_id = set(df_affiliations['affiliation_id'].tolist())
set_data_affiliations_id = set(df_reference_data['aff_scopus_id'].unique().tolist())
diff = set_affiliations_id.union(set_data_affiliations_id)  - set_affiliations_id.intersection(set_data_affiliations_id) 
diff
# Out:
# {'0', 'temp_008', 'temp_009'}

# %% [markdown]
# ### Si diff != 1

# %%
#exemple pour retrouver le libellé d'un aff_scopus_id
df[df["@afids"] == "temp_009"].mentionAffil_reconstruct
# Out:
# 18258    MajuLab, CNRS, Université de Nice, NUS-NTU Int...
# 19714    MajuLab., CNRS-Université Nice Sophia Antipoli...
# 23787    MajuLab, CNRS, Université de Nice, NUS-NTU Int...
# 23788    MajuLab, CNRS, Université de Nice, NUS-NTU Int...
# 23885    MajuLab, CNRS-UNS-NUS-NTU, Université Côte d'A...
#                                ...
# 42604    MajuLab, International Joint Research Unit IRL...
# 42951    MajuLab, International Joint Research Unit IRL...
# 42952    MajuLab, International Joint Research Unit IRL...
# 42991    MajuLab, International Joint Research Unit UMI...
# 43302    CRHEA-CNRS, Rue Bernard Gregory| MajuLab, Inte...
# Name: mentionAffil_reconstruct, Length: 104, dtype: object

# %% [markdown]
# - Ajouter à la main les nouvelles structures 03_primary/referentiel_structures.json
# - Compléter avec les ids trouvés (Hal, Idref...)
# - Incrémenter le champ id
# - Vérifier le parent_id
# - Mettre le nb documents_count à 0

# %% [markdown]
# ### Vérifs éditeurs à ajouter

# %%
def keep_duplicate (row):
    return row["author_name"] +"|" + row["affiliation_name"]
crfprefix_base_url = "https://api.crossref.org/v1/prefixes/"
def crf_publisher_metadata(prefix):
    """Get the homogeneous publisher's name from a prefix doi"""
    if prefix is None:
        raise ValueError('prefix cannot be None')
    result = {}
    result["prefix"] = prefix
    try:
        requests.get(crfprefix_base_url+str(prefix))
        if requests.get(crfprefix_base_url+str(prefix)).status_code == 200:
            response = requests.get(crfprefix_base_url+str(prefix)).text
            result["publisher_by_doiprefix"] = json.loads(response).get("message")["name"]
        else:
            pass
    except:
        pass
    return result

def crf_publisher_retrieval(doiprefix_list):
    """Request function crf_publisher_metadata from a list of doi prefixs and compile in a dataframe"""
    df_result = pd.DataFrame(crf_publisher_metadata(i) for i in doiprefix_list)
    return df_result[df_result["prefix"].notna()]

# %%
df_affiliations = pd.read_json('03_primary/referentiel_structures.json')

# %%
df_affiliations["affiliation_id"] = df_affiliations["affiliation_id"].astype('str')
df_reference_data["aff_scopus_id"] = df_reference_data["aff_scopus_id"].astype('str')
publis_all_with_affiliations_data = pd.merge(df_reference_data,df_affiliations[df_affiliations["affiliation_id"].notna()], left_on='aff_scopus_id', right_on='affiliation_id',how="left").drop(columns=['affiliation_id','documents_count','ppn_valide','affcourt_valide','RNSR','VIAF','ISNI','BNF','HAL'])
publis_all_with_affiliations_data = publis_all_with_affiliations_data.rename(columns={'id': 'aff_internal_id', 'parent_id': 'aff_parent_id'})
# identify corresponding author if UCA
publis_all_with_affiliations_data["corresponding"] = publis_all_with_affiliations_data[publis_all_with_affiliations_data["corresponding_author"] == "oui"].apply (lambda row: keep_duplicate(row), axis=1)

# %%
publis_all_with_affiliations_data["corresponding_author"] = publis_all_with_affiliations_data["corresponding_author"].astype('category')
publis_all_with_affiliations_data["corresponding_author"] = publis_all_with_affiliations_data["corresponding_author"].cat.set_categories(['oui', 'non', 'corr absent pour cette publi'], ordered=True)
publis_all_with_affiliations_data.sort_values(by=['doi', 'corresponding_author'])
publis_uniques_doi_data = publis_all_with_affiliations_data[publis_all_with_affiliations_data.doi.notna()].drop_duplicates(subset=['doi'], keep='first')[["source_id","doi","year","corresponding","all_authors"]]
publis_uniques_doi_data = publis_uniques_doi_data[publis_uniques_doi_data.year < int(corpus_end_year)]

# %%
new_prefix_list = list(set([item.partition("/")[0] for item in publis_uniques_doi_data["doi"].to_list()]))
old_prefix_df = pd.read_csv('03_primary/mapping_doiprefixes_publisher.csv', sep=",",encoding='utf8')
old_prefix_list = old_prefix_df["prefix"].astype(str).to_list()
diff_prefix_list = list(set(new_prefix_list) - set(old_prefix_list))
diff_prefix_list
# Out:
# ['10.5220',
#  '10.7150',
#  '10.22564',
#  '10.17396',
#  '10.1210',
#  '10.1200',
#  '10.21630',
#  '10.3390',
#  '10.1130',
#  '10.5210',
#  '10.25537',
#  '10.25428',
#  '10.9876',
#  '10.14601',
#  '10.24820',
#  '10.30549',
#  '10.22201',
#  '10.5441',
#  '10.3750',
#  '10.1070',
#  '10.2383',
#  '10.2110',
#  '10.5840',
#  '10.6092',
#  '10.1590',
#  '10.5277',
#  '10.14658',
#  '10.1080',
#  '10.21409',
#  '10.13128',
#  '10.2340',
#  '10.2423',
#  '10.1190',
#  '10.3150',
#  '10.1439',
#  '10.24310',
#  '10.1680',
#  '10.19272',
#  '10.11936',
#  '10.5278',
#  '10.20960',
#  '10.35470',
#  '10.14649',
#  '10.57',
#  '10.1160',
#  '10.11909',
#  '10.2312',
#  '10.26331',
#  '10.4310',
#  '10.4418',
#  '10.1482',
#  '10.26028',
#  '10.31009',
#  '10.7410',
#  '10.48611',
#  '10.34190',
#  '10.1530',
#  '10.1140',
#  '10.13130',
#  '10.4230',
#  '10.3240',
#  '10.32473',
#  '10.3290',
#  '10.21411',
#  '10.17660',
#  '10.4454',
#  '10.1090',
#  '10.24840',
#  '10.3850',
#  '10.4000',
#  '10.2140']

# %%
df_new_prefix_result = crf_publisher_retrieval(diff_prefix_list)
publishers_doi_prefix = old_prefix_df.append(df_new_prefix_result)

# %%
publishers_doi_prefix
# Out:
#       prefix                           publisher_by_doiprefix
# 0   10.21873                     Anticancer Research USA Inc.
# 1    10.1119  American Association of Physics Teachers (AAPT)
# 2    10.2166                                   IWA Publishing
# 3    10.1177                                SAGE Publications
# 4    10.4081                           PAGEPress Publications
# ..       ...                                              ...
# 66   10.1090              American Mathematical Society (AMS)
# 67  10.24840                              University of Porto
# 68   10.3850                     Research Publishing Services
# 69   10.4000                                              NaN
# 70   10.2140                                              NaN
#
# [439 rows x 2 columns]

# %%
publishers_doi_prefix.drop_duplicates(subset=['prefix'], keep='last').to_csv('03_primary/mapping_doiprefixes_publisher.csv', index = False,encoding='utf8')

# %% [markdown]
# ## Divers

# %%
df_affiliations.columns
# Out:
# Index(['affiliation_name', 'affiliation_id', 'ppn_valide', 'affcourt_valide',
#        'RNSR', 'VIAF', 'ISNI', 'BNF', 'HAL', 'id', 'parent_id',
#        'documents_count'],
#       dtype='object')

# %%
df_count = df_reference_data.groupby("aff_scopus_id")['doi'].nunique().reset_index().rename(columns={'doi':'counts'}).convert_dtypes()
df_affiliations = pd.merge(df_affiliations,df_count, left_on='affiliation_id', right_on='aff_scopus_id',how="left").drop(columns=['aff_scopus_id','documents_count']).rename(columns={'counts':'documents_count'})

# %%
df_affiliations
# Out:
#                                      affiliation_name affiliation_id  \
# 0                                    UCA (Université)              0
# 1                                                 OCA              0
# 2                                         Villa Arson              0
# 3                                   UCA (affiliation)       60110693
# 4   Institut de Pharmacologie Moléculaire et Cellu...       60006380
# 5   Centre de Recherche sur l'Hétéro-Epitaxie et s...       60006696
# 6                      Observatoire de la Côte d'Azur       60010513
# 7                              Le Laboratoire Géoazur       60101367
# 8   Étude des Structures et des Processus d’Adapta...       60107106
# 9                  Laboratoire Souterrain à Bas Bruit       60107140
# 10        Laboratoire de Mathématiques J.A. Dieudonné       60110369
# 11                     Cognition Behaviour Technology       60110689
# 12  Transporteurs en Imagerie et Radiothérapie en ...       60110690
# 13       Microbiologie Orale, Immunothérapie et Santé       60110692
# 14       Centre Méditerranéen de Médecine Moléculaire       60110695
# 15  Institut de Recherche sur le Cancer et le Viei...       60110697
# 16        Centre de Recherches en Histoires des Idées       60110704
# 17           Unité de Recherche Migrations et Société       60110705
# 18  Groupe de Recherche en Droit, Économie et Gestion       60110706
# 19  Laboratoire Interdisciplinaire Récits, Culture...       60110707
# 20  Centre Transdisciplinaire D'épistémologie de l...       60110708
# 21            Information Milieux, Médias, Médiations       60110709
# 22  Laboratoire d'Anthropologie et de Psychologie ...       60110710
# 23  Laboratoire Motricité Humaine Expertise Sport ...       60110712
# 24  Centre de la Méditerranée Moderne et Contempor...       60110714
# 25                Institut Sophia Agrobiotech - (ISA)       60110715
# 26  Equipe de Recherche sur les Mutations de I'Eur...       60110716
# 27  Ecology and Conservation Science for Sustainab...       60110717
# 28  Laboratoire D'informatique Signaux et Systèmes...       60110719
# 29                  Groupe de Recherche en Management       60110721
# 30                       Institut de Physique de Nice       60110740
# 31                           Laboratoire Polytech'LAB       60110741
# 32  Astrophysique Relativiste, Théories, Expérienc...       60110743
# 33                  Laboratoire Joseph-Louis Lagrange       60110744
# 34  Laboratoire D'électronique, Antennes et Téléco...       60110755
# 35                       Institut de Biologie Valrose       60110756
# 36             Centre Commun de Microscopie Appliquée       60110760
# 37           Laboratoire de Physiomédecine Moléulaire       60110761
# 38                           Bases, Corpus et Langage       60110762
# 39                         Institut de Chimie de Nice       60110763
# 40  Cultures et Envirronements, Préhistoire, Antiq...       60110764
# 41  Unite de Pharmacogenetique et Radiogenetique d...       60111234
# 42                                        Villa Arson       60122129
# 43                                   NICE Lab, IMREDD       temp_001
# 44  Laboratoire d'Innovation et Numérique pour l'É...       temp_002
# 45                                               EpoC       temp_003
# 46   Center of Modeling, Simulation, and Interactions       temp_004
# 47                                              LADIE       temp_005
# 48  Interdisciplinary Institute for Artificial Int...       temp_006
# 49  Unité de Recherche Clinique de la Côte d’Azur,...       temp_007
# 50                                         UNS divers       60033148
#
#    ppn_valide                                    affcourt_valide        RNSR  \
# 0
# 1
# 2
# 3
# 4   05957321X  Institut de pharmacologie moléculaire et cellu...  201220332C
# 5   060408278  Centre de recherche sur l'hétéro-épitaxie et s...  200017509L
# 6   035675683                     Observatoire de la Côte d'Azur
# 7   172062225  Laboratoire Géoazur (Sophia Antipolis, Alpes-M...  200816914E
# 8   182401367  Étude des structures, des processus d'adaptati...  201220240C
# 9   234479388                 Laboratoire Souterrain à Bas Bruit  201220901W
# 10  060325887                 Laboratoire J.-A. Dieudonné (Nice)  201220430J
# 11  168085461              Cognition Behaviour Technology (Nice)  201220412P
# 12  228218861  Transporteurs en Imagerie et Radiothérapie en ...  200815550X
# 13  191161470       Microbiologie Orale, Immunothérapie et Santé  201521255T
# 14  161561578  Centre Méditerranéen de Médecine Moléculaire (...  201220149D
# 15  184404983  Institut de recherche sur le cancer et le viei...  201220417V
# 16  026366584  Centre de recherche en histoire des idées. EA ...  200815548V
# 17  201169754  Unité de recherche Migrations et Société. UMR ...  200919202M
# 18  142564443  Groupe de recherche en droit, é9conomie et ges...  201220333D
# 19  166052167  Laboratoire interdisciplinaire Récits Cultures...  200014458V
# 20  183657101  Centre transdisciplinaire d’épistémologie de l...  201220285B
# 21  099102609  Laboratoire de recherche Information, milieux,...  200415080D
# 22  227478819  Laboratoire d'anthropologie et de psychologie ...  201220397Y
# 23  177808659  Laboratoire Motricité Humaine, Expertise, Spor...  201220315J
# 24  026568810  Centre de la Méditerranée moderne et contempor...  199213380H
# 25  170849007  Institut Sophia Agrobiotech (Sophia Antipolis,...  201220409L
# 26
# 27
# 28
# 29  168839318           Groupe de recherche en management (Nice)  201220245H
# 30  223644501                       Institut de Physique de Nice  201722398B
# 31  228311748                                       Polytech'Lab
# 32  18467543X  Astrophysique Relativiste Théories Expériences...  201220434N
# 33  172058155  Laboratoire Joseph-Louis Lagrange (Nice, Alpes...  201220431K
# 34  06032466X  Laboratoire d'électronique, antennes et téléco...  201220433M
# 35  178149357                       Institut de biologie Valrose  201220170B
# 36
# 37  186256728  Laboratoire de PhysioMédecine Moléculaire (Nic...  201220337H
# 38  200912003     Bases, Corpus, Langage. UMR 7320 (Nice ; 2012-  201220287D
# 39  172175038         Institut de chimie (Nice, Alpes-Maritimes)  201220250N
# 40  078599725  Cultures et Environnements. Préhistoire, Antiq...  201220314H
# 41
# 42  02643587X                                 Villa Arson (Nice)
# 43  224352008                                       N.I.C.E. Lab  201622217J
# 44
# 45  191470287  Électronique pour Objets Connectés (Biot, Alpe...  201320649T
# 46
# 47
# 48
# 49
# 50
#
#                       VIAF              ISNI                      BNF  \
# 0
# 1
# 2
# 3
# 4                132291546  0000000406380649
# 5                219301530
# 6                148948947  0000000121815557  /ark:/12148/cb133287471
# 7                305306224  0000000098886911
# 8                304538672  0000000090681030  /ark:/12148/cb16692863g
# 9   3320157100620972740006
# 10               148604182
# 11               298589068
# 12  3219153126233224750002
# 13   248145858118423022096
# 14               306309768  0000000406205402
# 15               315252262  0000000483403111
# 16               132049353  0000000106616912  /ark:/12148/cb11862817b
# 17   236145542825896642454
# 18               196245953  0000000406380614  /ark:/12148/cb16583870m
# 19               285434197  0000000115200206
# 20               148060585  0000000119419213
# 21               158643734                    /ark:/12148/cb150467529
# 22  9283153126249124750002  0000000453743481
# 23               308309148
# 24               150860870  0000000121847444  /ark:/12148/cb11879136k
# 25               149289501  0000000403858766
# 26
# 27
# 28
# 29               299827864
# 30   170151837978720520006  0000000474344738
# 31  5519153126239524750006
# 32               315728737  0000000403853172
# 33               305306142  0000000403855397
# 34               313172580  0000000403850836
# 35               308790354  0000000406096787
# 36
# 37               316676984
# 38   641149719128211130006  0000000095125922
# 39               305396234  0000000403848488
# 40               143167470  0000000121738926  /ark:/12148/cb13751539g
# 41
# 42               136763798  0000000093163263  /ark:/12148/cb118683836
# 43  4338152080596707230000
# 44
# 45   719145858088323021910
# 46
# 47
# 48
# 49
# 50
#
#          HAL  id  parent_id  documents_count
# 0              1          0             <NA>
# 1              2          0             <NA>
# 2              3          0             <NA>
# 3              4          1             4297
# 4     199361   5          1              653
# 5        409   6          1              364
# 6              7          2              393
# 7              8          2              873
# 8      87217   9          1              124
# 9             10          1               20
# 10    199970  11          1             1185
# 11    168629  12          1              193
# 12    238190  13          1               90
# 13    450080  14          1               78
# 14    180122  15          1              976
# 15    182186  16          1              730
# 16      1723  17          1                6
# 17   1004973  18          1               49
# 18    185786  19          1              492
# 19    227789  20          1               18
# 20    424925  21          1                3
# 21            22          1                3
# 22    530129  23          1              132
# 23     54697  24          1              406
# 24     30708  25          1               13
# 25   1002392  26          1              664
# 26            27          1                9
# 27            28          1              170
# 28            29          1             1072
# 29    520677  30          1               51
# 30    497162  31          1              897
# 31    537646  32          1              149
# 32            33          2              294
# 33            34          2             1693
# 34    193834  35          1              260
# 35    182201  36          1              591
# 36            37          1               96
# 37    201743  38          1              122
# 38  60110762  39          1               97
# 39    212876  40          1              579
# 40    199355  41          1              219
# 41            42          1               19
# 42            43          3                2
# 43            44          1               76
# 44            45          1               21
# 45            46          1               21
# 46            47          1               15
# 47            48          1                2
# 48   1090027  50          1               14
# 49   1048785  51          1               50
# 50            49          1                5
